# %% [markdown]
# # Chargement PTB

# %%
import sys
# !{sys.executable} -m pip install -U kagglehub
import kagglehub
# Download latest version
path = kagglehub.dataset_download("abhirampolisetti/ptb-diagnostic-ecg-database")

print("Path to dataset files:", path)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]
# ...
# 100%|██████████| 1.61G/1.61G [10:09<00:00, 2.84MB/s]
# Extracting files...
# Path to dataset files: /Users/raphc/.cache/kagglehub/datasets/abhirampolisetti/ptb-diagnostic-ecg-database/versions/1
